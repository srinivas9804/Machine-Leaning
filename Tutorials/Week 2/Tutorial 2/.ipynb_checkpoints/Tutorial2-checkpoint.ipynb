# %% [markdown]
# **Name:** SIVAKUMAR Srinivas
#
# **EID:** 54486977_

# %% [markdown]
# # CS4487 - Tutorial 2
# ## Text Document Classification with Naive Bayes
#
# In this tutorial you will classify text documents using Naive Bayes classifers.  We will be working with the dataset called "20 Newsgroups", which is a collection of 20,000 newsgroup posts organized into 20 categories.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
from scipy import stats
random.seed(100)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# D:\Anaconda3\lib\site-packages\sklearn\learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %% [markdown]
# Next, put the file "20news-bydate_py3.pkz' into the same directory as this ipynb file. **Do not unzip the file.**

# %% [markdown]
# Next, we will extract 4 classes from the dataset.  Run the below cell.

# %%
# strip away headers/footers/quotes from the text
removeset = ('headers', 'footers', 'quotes')

# only use 4 categories
cats      = ['alt.atheism', 'talk.religion.misc', 'comp.graphics', 'sci.space']

# load the training and testing sets
newsgroups_train = datasets.fetch_20newsgroups(subset='train',
                           remove=removeset, categories=cats, data_home='./')
newsgroups_test  = datasets.fetch_20newsgroups(subset='test', 
                           remove=removeset, categories=cats, data_home='./')

# %% [markdown]
# Now, we check if we got all the data.  The training set should have 2034 documents, and the test set should have 1353 documents.

# %%
print("training set size:", len(newsgroups_train.data))
print("testing set size: ",  len(newsgroups_test.data))
print(newsgroups_train.target_names)
# Out:
# training set size: 2034
# testing set size:  1353
# ['alt.atheism', 'comp.graphics', 'sci.space', 'talk.religion.misc']

# %% [markdown]
# Count the number examples in each class.  `newsgroups_train.target` is an array of class values (0 through 3), and `newsgroups_train.target[i]` is the class of the i-th document.

# %%
print("class counts")
for i in [0, 1, 2, 3]:
    print("{:20s}: {}".format(newsgroups_train.target_names[i], sum(newsgroups_train.target == i)))
# Out:
# class counts
# alt.atheism         : 480
# comp.graphics       : 584
# sci.space           : 593
# talk.religion.misc  : 377

# %% [markdown]
# Now have a look at the documents.  `newsgroups_train.data` is a list of strings, and `newsgroups_train.data[i]` is the i-th document.

# %%
for i in [0, 1, 2 ,3]:
    print("--- document {} (class={}) ---".format(
        i, newsgroups_train.target_names[newsgroups_train.target[i]]))
    print(newsgroups_train.data[i])
# Out:
# --- document 0 (class=comp.graphics) ---
# Hi,
#
# I've noticed that if you only save a model (with all your mapping planes
# positioned carefully) to a .3DS file that when you reload it after restarting
# 3DS, they are given a default position and orientation.  But if you save
# to a .PRJ file their positions/orientation are preserved.  Does anyone
# know why this information is not stored in the .3DS file?  Nothing is
# explicitly said in the manual about saving texture rules in the .PRJ file.
# I'd like to be able to read the texture rule information, does anyone have
# the format for the .PRJ file?
#
# Is the .CEL file format available from somewhere?
#
# Rych
# --- document 1 (class=talk.religion.misc) ---
#
#
# Seems to be, barring evidence to the contrary, that Koresh was simply
# another deranged fanatic who thought it neccessary to take a whole bunch of
# folks with him, children and all, to satisfy his delusional mania. Jim
# Jones, circa 1993.
#
#
# Nope - fruitcakes like Koresh have been demonstrating such evil corruption
# for centuries.
# --- document 2 (class=sci.space) ---
#
#  >In article <1993Apr19.020359.26996@sq.sq.com>, msb@sq.sq.com (Mark Brader)
#
# MB>                                                             So the
# MB> 1970 figure seems unlikely to actually be anything but a perijove.
#
# JG>Sorry, _perijoves_...I'm not used to talking this language.
#
# Couldn't we just say periapsis or apoapsis?
#
#
# --- document 3 (class=alt.atheism) ---
# I have a request for those who would like to see Charley Wingate
# respond to the "Charley Challenges" (and judging from my e-mail, there
# appear to be quite a few of you.)
#
# It is clear that Mr. Wingate intends to continue to post tangential or
# unrelated articles while ingoring the Challenges themselves.  Between
# the last two re-postings of the Challenges, I noted perhaps a dozen or
# more posts by Mr. Wingate, none of which answered a single Challenge.
#
# It seems unmistakable to me that Mr. Wingate hopes that the questions
# will just go away, and he is doing his level best to change the
# subject.  Given that this seems a rather common net.theist tactic, I
# would like to suggest that we impress upon him our desire for answers,
# in the following manner:
#
# 1. Ignore any future articles by Mr. Wingate that do not address the
# Challenges, until he answers them or explictly announces that he
# refuses to do so.
#
# --or--
#
# 2. If you must respond to one of his articles, include within it
# something similar to the following:
#
#     "Please answer the questions posed to you in the Charley Challenges."
#
# Really, I'm not looking to humiliate anyone here, I just want some
# honest answers.  You wouldn't think that honesty would be too much to
# ask from a devout Christian, would you?
#
# Nevermind, that was a rhetorical question.

# %% [markdown]
# **Tip:** while you do the tutorial, it is okay to make additional code cells in the file.  This will allow you to avoid re-running code (like training a classifier, then testing a classifier).

# %% [markdown]
# ### 1. Build document vectors
# Create the vocabulary from the training data.  Then build the document vectors for the training and testing sets.  You can decide how many words you want in the vocabulary.

# %%
### INSERT YOUR CODE HERE
cntvect = feature_extraction.text.CountVectorizer(stop_words='english', max_features=150)
trainX = cntvect.fit_transform(newsgroups_train.data)
testX  = cntvect.transform(newsgroups_test.data)
print(cntvect.vocabulary_)
# Out:
# {'ve': 140, 'file': 39, 'given': 47, 'does': 29, 'know': 63, 'information': 58, 'said': 115, 'like': 68, 'read': 108, 'format': 42, 'available': 7, 'evidence': 34, 'thought': 133, '1993': 1, 'com': 20, 'actually': 3, 'used': 138, 'just': 62, 'say': 117, 'mail': 77, 'quite': 107, 'post': 99, 'following': 41, 'really': 110, 'want': 142, 'think': 132, 'christian': 17, 'question': 106, 'lunar': 76, 'atheists': 6, 'sure': 127, 'list': 70, 'bit': 12, 'example': 35, 'probably': 101, 'note': 90, 'data': 24, 'non': 89, 'earth': 32, 'space': 124, '20': 2, 'software': 123, 'computer': 22, 'support': 126, 'real': 109, 'time': 134, 'll': 72, 'things': 131, 'don': 31, 'doesn': 30, 'mission': 82, 'orbit': 92, 'using': 139, 'moon': 83, 'thing': 130, 'far': 38, 'believe': 9, 'image': 56, 'graphics': 52, 'thanks': 129, 'good': 50, 'look': 74, 'didn': 27, 'images': 57, 'program': 103, 'need': 86, 'edu': 33, 'systems': 128, 'possible': 98, 'better': 10, 'case': 15, 'number': 91, 'make': 78, 'news': 88, 'general': 45, 'right': 114, 'people': 95, 'mean': 80, 'world': 146, 'did': 26, 'set': 120, 'year': 148, 'law': 65, 'point': 97, 'argument': 4, 'way': 143, 'try': 136, 'based': 8, 'wrong': 147, 'true': 135, 'course': 23, 'moral': 84, 'years': 149, 'fact': 36, 'use': 137, 'bible': 11, 'going': 49, 'programs': 104, 'lot': 75, 'called': 14, 'isn': 59, 'person': 96, 'problem': 102, 'means': 81, 'new': 87, 'small': 122, 'god': 48, 'got': 51, 'let': 66, 'work': 145, 'line': 69, 'color': 19, 'order': 93, 'come': 21, 'high': 55, 'atheism': 5, 'package': 94, 'sun': 125, 'help': 54, 'little': 71, 'man': 79, 'free': 43, 'research': 113, 'religion': 111, 'jesus': 60, 'long': 73, 'day': 25, 'religious': 112, 'satellite': 116, 'power': 100, 'life': 67, 'group': 53, 'version': 141, 'different': 28, 'book': 13, 'word': 144, '10': 0, 'pub': 105, 'gif': 46, 'code': 18, 'files': 40, 'launch': 64, 'send': 119, 'ftp': 44, 'science': 118, 'nasa': 85, 'center': 16, 'shuttle': 121, 'faq': 37, 'jpeg': 61}

# %%
def showVocab(vocab, counts=None):
    "print out the vocabulary. if counts specified, then only print the words w/ non-zero entries"
    allwords = list(vocab.keys())
    allwords.sort()  # sort vocabulary by index
    wordlist = []
    for word in allwords:
        ind = vocab[word]
        if (counts is None):
            mystr = "{:3d}. {}".format(ind, word)
        elif (counts[0,ind]>0):
            mystr = "{:3d}. ({:0.4f}) {}".format(ind, counts[0,ind], word)
        else:
            continue  # skip it
        wordlist.append(mystr)

    # print 2 columns
    it = iter(wordlist)
    try:
        for i in it:
            print('{:<30}{}'.format(i, next(it)))
    except StopIteration:
        pass
    finally:
        del it

            
# show the vocabulary
showVocab(cntvect.vocabulary_)
# Out:
#   0. 10                         1. 1993
#   2. 20                         3. actually
#   4. argument                   5. atheism
#   6. atheists                   7. available
#   8. based                      9. believe
#  10. better                    11. bible
#  12. bit                       13. book
#  14. called                    15. case
#  16. center                    17. christian
#  18. code                      19. color
#  20. com                       21. come
#  22. computer                  23. course
#  24. data                      25. day
#  26. did                       27. didn
#  28. different                 29. does
#  30. doesn                     31. don
#  32. earth                     33. edu
#  34. evidence                  35. example
#  36. fact                      37. faq
#  38. far                       39. file
#  40. files                     41. following
#  42. format                    43. free
#  44. ftp                       45. general
#  46. gif                       47. given
#  48. god                       49. going
#  50. good                      51. got
#  52. graphics                  53. group
#  54. help                      55. high
#  56. image                     57. images
#  58. information               59. isn
#  60. jesus                     61. jpeg
#  62. just                      63. know
#  64. launch                    65. law
#  66. let                       67. life
#  68. like                      69. line
#  70. list                      71. little
#  72. ll                        73. long
#  74. look                      75. lot
#  76. lunar                     77. mail
#  78. make                      79. man
#  80. mean                      81. means
#  82. mission                   83. moon
#  84. moral                     85. nasa
#  86. need                      87. new
#  88. news                      89. non
#  90. note                      91. number
#  92. orbit                     93. order
#  94. package                   95. people
#  96. person                    97. point
#  98. possible                  99. post
# 100. power                    101. probably
# 102. problem                  103. program
# 104. programs                 105. pub
# 106. question                 107. quite
# 108. read                     109. real
# 110. really                   111. religion
# 112. religious                113. research
# 114. right                    115. said
# 116. satellite                117. say
# 118. science                  119. send
# 120. set                      121. shuttle
# 122. small                    123. software
# 124. space                    125. sun
# 126. support                  127. sure
# 128. systems                  129. thanks
# 130. thing                    131. things
# 132. think                    133. thought
# 134. time                     135. true
# 136. try                      137. use
# 138. used                     139. using
# 140. ve                       141. version
# 142. want                     143. way
# 144. word                     145. work
# 146. world                    147. wrong
# 148. year                     149. years

# %%
showVocab(cntvect.vocabulary_, trainX[0])
print("---")
print(newsgroups_train.data[0])
# Out:
#   7. (1.0000) available        29. (2.0000) does
#  39. (6.0000) file             42. (2.0000) format
#  47. (1.0000) given            58. (2.0000) information
#  63. (1.0000) know             68. (1.0000) like
# 108. (1.0000) read            115. (1.0000) said
# ---
# Hi,
#
# I've noticed that if you only save a model (with all your mapping planes
# positioned carefully) to a .3DS file that when you reload it after restarting
# 3DS, they are given a default position and orientation.  But if you save
# to a .PRJ file their positions/orientation are preserved.  Does anyone
# know why this information is not stored in the .3DS file?  Nothing is
# explicitly said in the manual about saving texture rules in the .PRJ file.
# I'd like to be able to read the texture rule information, does anyone have
# the format for the .PRJ file?
#
# Is the .CEL file format available from somewhere?
#
# Rych

# %% [markdown]
# ### 2. Bernoulli Naive Bayes
# Learn a Bernoulli Naive Bayes model from the training set.  What is the prediction accuracy on the test set?  Try different parameters (alpha, max_features, etc) to get the best performance.

# %%
### INSERT YOUR CODE HERE
bmodel = naive_bayes.BernoulliNB(alpha=0.1)
bmodel.fit(trainX, newsgroups_train.target)
# Out:
# BernoulliNB(alpha=0.1, binarize=0.0, class_prior=None, fit_prior=True)

# %% [markdown]
# What are the most informative words for each category?  Run the below code.
#
# Note: `model.coef_[i]` will index the scores for the i-th class

# %%
# get the word names
fnames = asarray(cntvect.get_feature_names())
for i,c in enumerate(newsgroups_train.target_names):
    tmp = argsort(bmodel.coef_[i])[-10:]
    print("class", c)
    for t in tmp:
        print("    {:9s} ({:.5f})".format(fnames[t], bmodel.coef_[i][t]))
# Out:
# class alt.atheism
#     time      (-1.80349)
#     does      (-1.60881)
#     know      (-1.60881)
#     god       (-1.58822)
#     like      (-1.54825)
#     say       (-1.52885)
#     just      (-1.45481)
#     think     (-1.39424)
#     people    (-1.29824)
#     don       (-1.18991)
# class comp.graphics
#     just      (-1.95020)
#     don       (-1.91473)
#     program   (-1.88048)
#     need      (-1.85829)
#     does      (-1.74429)
#     use       (-1.73454)
#     like      (-1.60722)
#     know      (-1.50966)
#     graphics  (-1.49428)
#     thanks    (-1.47166)
# class sci.space
#     earth     (-1.90706)
#     use       (-1.88461)
#     time      (-1.76942)
#     know      (-1.73062)
#     think     (-1.73062)
#     nasa      (-1.73062)
#     don       (-1.69327)
#     just      (-1.47214)
#     like      (-1.41502)
#     space     (-1.01909)
# class talk.religion.misc
#     say       (-1.65472)
#     way       (-1.62736)
#     like      (-1.61395)
#     does      (-1.53709)
#     know      (-1.48895)
#     think     (-1.42082)
#     god       (-1.37785)
#     don       (-1.35703)
#     just      (-1.34679)
#     people    (-1.31667)

# %%
predY = bmodel.predict(testX)
print("predictions: ", predY)
print("actual:      ", newsgroups_train.target)
acc = metrics.accuracy_score(newsgroups_test.target, predY)
print(acc)
# Out:
# predictions:  [1 1 1 ... 1 1 1]
# actual:       [1 3 2 ... 1 0 1]
# 0.6023651145602366

# %% [markdown]
# ### 3. Multinomial Naive Bayes model
# Now learn a multinomial Naive Bayes model using the TF-IDF representation for the documents.  Again try different parameter values to improve the test accuracy.

# %%
### INSERT YOUR CODE HERE
tf_trans = feature_extraction.text.TfidfTransformer(use_idf=True, norm='l1')
trainXtf = tf_trans.fit_transform(trainX)
testXtf = tf_trans.transform(testX)
mmodel_tf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3f392eb7ed20> in <module>()
#       3 trainXtf = tf_trans.fit_transform(trainX)
#       4 testXtf = tf_trans.transform(testX)
# ----> 5 mmodel_tf
#
# NameError: name 'mmodel_tf' is not defined

# %%
showVocab(cntvect.vocabulary_, trainXtf[0])
# Out:
#   7. (0.0552) available        29. (0.0797) does
#  39. (0.3505) file             42. (0.1312) format
#  47. (0.0550) given            58. (0.1093) information
#  63. (0.0374) know             68. (0.0366) like
# 108. (0.0498) read            115. (0.0487) said

# %%
def trainMultinomialBayes(val=0.2):
    global mmodel_tf
    mmodel_tf = naive_bayes.MultinomialNB(alpha=val)
    mmodel_tf.fit(trainXtf, newsgroups_train.target)

# %% [markdown]
# What are the most informative features for Multinomial model? Run the below code.

# %%
# get the word names
trainMultinomialBayes()
fnames = asarray(cntvect.get_feature_names())
for i,c in enumerate(newsgroups_train.target_names):
    tmp = argsort(mmodel_tf.coef_[i])[-10:]
    print("class", c)
    for t in tmp:
        print("    {:9s} ({:.5f})".format(fnames[t], mmodel_tf.coef_[i][t]))
# Out:
# class alt.atheism
#     said      (-4.12626)
#     religion  (-3.99749)
#     say       (-3.95039)
#     know      (-3.94547)
#     does      (-3.82174)
#     think     (-3.77498)
#     just      (-3.76484)
#     people    (-3.64311)
#     don       (-3.61738)
#     god       (-3.31522)
# class comp.graphics
#     edu       (-4.06097)
#     use       (-4.03683)
#     need      (-4.03012)
#     file      (-3.86164)
#     image     (-3.84778)
#     files     (-3.84350)
#     know      (-3.77341)
#     does      (-3.74887)
#     thanks    (-3.39766)
#     graphics  (-3.28395)
# class sci.space
#     moon      (-4.27549)
#     don       (-4.26917)
#     time      (-4.26823)
#     launch    (-4.24718)
#     think     (-4.23713)
#     orbit     (-4.06079)
#     nasa      (-3.91483)
#     just      (-3.79134)
#     like      (-3.76594)
#     space     (-2.89299)
# class talk.religion.misc
#     say       (-4.08778)
#     like      (-4.06931)
#     know      (-4.04062)
#     don       (-3.99630)
#     think     (-3.98155)
#     christian (-3.96292)
#     just      (-3.92911)
#     people    (-3.81091)
#     jesus     (-3.64163)
#     god       (-3.29888)

# %%
def testMultinomialBayes():
    global predYtf
    predYtf = mmodel_tf.predict(testXtf)
    #print("prediction: ", predYtf)
    #print("actual:     ", newsgroups_test.target)
    acc = metrics.accuracy_score(newsgroups_test.target, predYtf)
    #print(acc)
    return acc

# %% [markdown]
# How do the most informative words differ between the TF-IDF multinomial model and the Bernoulli model?

# %% [markdown]
# - The TF-IDF model ignores words which appear in multiple different classes and tries to give importance to words which appear only in that specific class. Take the class comp.graphics for example, in the bernoulli model, words like 'just' and 'like' are common but these are common words which will be in different classes. In the TF-IDF model these words are replaced with more specific words of that class like 'file' and 'image'.

# %% [markdown]
# Finally, look at a few of the misclassified documents/.

# %%
### INSERT YOUR CODE HERE ###
testMultinomialBayes()
ctr = 0 
#having a look at the first 10 misclassified elements
for i in range(len(predYtf)):
    if ctr > 10:
        break
    if predYtf[i] != newsgroups_test.target[i]:
        print("actual value : ",newsgroups_test.target[i],"predicted value : ",predYtf[i])
        ctr = ctr + 1
# Out:
# actual value :  0 predicted value :  3
# actual value :  0 predicted value :  2
# actual value :  2 predicted value :  1
# actual value :  3 predicted value :  2
# actual value :  3 predicted value :  0
# actual value :  3 predicted value :  0
# actual value :  0 predicted value :  2
# actual value :  3 predicted value :  0
# actual value :  0 predicted value :  1
# actual value :  3 predicted value :  0
# actual value :  3 predicted value :  0

# %% [markdown]
# Can you get any intuition or reason why they were misclassified?

# %% [markdown]
# - Classes 0 and 3 are generally misclassified as the other. This is because atheism and religion are two topics which are inter-linked. The text will contain similar phrases and will talk about the other topic, hence it is more difficult to classify them.

# %% [markdown]
# ### 4. Effect of smoothing
# The smoothing (regularization) parameter has a big effect on the performance.  Using the Multinomial TF-IDF models, make a plot of accuracy versus different values of alpha. For each alpha, you need to train a new model. Which alpha value yields the best result?

# %%
### INSERT YOUR CODE HERE
alphavalues = logspace(-5,0,50)
max_acc = 0
max_alpha = 0
accuracy = []
for i in alphavalues:
    trainMultinomialBayes(i)
    temp = testMultinomialBayes()
    accuracy.append(temp)
    if temp > max_acc:
        max_acc = temp
        max_alpha = i
plt.figure()
plt.semilogx(alphavalues, accuracy)
plt.semilogx(max_alpha, max_acc, 'kx')
plt.xlabel('alpha'); plt.ylabel('accuracy')     
plt.grid(True)  
plt.title('accuracy versus alpha');

# %%
print('Max accuracy of classifer is :',max_acc," when alpha =",max_alpha)
# Out:
# Max accuracy of classifer is : 0.6459719142645972  when alpha = 0.0035564803062231283

# %% [markdown]
# ### 5. Effect of vocabulary size
# The vocabulary size also affects the accuracy.  Make another plot of accuracy versus vocabulary size.  Which vocabulary size yields the best result?

# %%
### INSERT YOUR CODE HERE

# %%
vocabsize = linspace(100,26000,20)
max_acc = 0
max_vocab = 0
accuracy = []
for i in vocabsize:
    cntvect = feature_extraction.text.CountVectorizer(stop_words='english', max_features=int(i))
    trainX = cntvect.fit_transform(newsgroups_train.data)
    testX  = cntvect.transform(newsgroups_test.data)
    tf_trans = feature_extraction.text.TfidfTransformer(use_idf=True, norm='l1')
    trainXtf = tf_trans.fit_transform(trainX)
    testXtf = tf_trans.transform(testX)
    trainMultinomialBayes(0.001)
    temp = testMultinomialBayes()
    accuracy.append(temp)
    if temp > max_acc:
        max_acc = temp
        max_vocab = i
plt.figure
plt.plot(vocabsize,accuracy)
plt.plot(max_vocab, max_acc, 'kx')
plt.grid(True)
plt.ylabel('accuracy')
plt.xlabel('vocabulary size')
plt.title('graph of vocabulary size vs accuracy')
plt.show()

# %%
print('Max accuracy of classifer is :',max_acc," when vocabulary size =",max_vocab)
# Out:
# Max accuracy of classifer is : 0.7804878048780488  when vocabulary size = 23273.684210526317
