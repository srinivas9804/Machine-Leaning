# %% [markdown]
# **Name:** SIVAKUMAR Srinivas
#
# **EID:** 54486977

# %% [markdown]
# # CS4487 - Tutorial 6
# ## Image Segmentation using Clustering
#
# In this tutorial you will use clustering algorithms to generate a segmentation of an image.  An image segmentation is a separation of an image into regions belonging to distinct objects.
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best) 
# jpg is better for images
IPython.core.display.set_matplotlib_formats("jpg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import glob
import os
import csv
import string
import skimage.io
import skimage.color
import skimage.util
random.seed(100)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# D:\Anaconda3\lib\site-packages\sklearn\learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the data.  Download `imgdb.zip`, and unzip it in the same directory as this ipynb file.  Then run the following cell to load the image data.

# %%
filelist = glob.glob('imgdb/jpg/*.jpg')
gtpath   = 'imgdb/gtruth/'
if len(filelist) == 0:
    warn.error("Could not find imgdb directory!  " + 
               "Make sure you put it here: " + os.getcwd() )
else:
    imgdata = []
    gtdata  = []
    
    # load image data
    for f in filelist:
        # load image - byte [0 to 255]
        img = skimage.io.imread(f)
        
        (fdir1, fname)  = os.path.split(f)        

        # load GT segmentation (non-consecutive integers)
        gname = gtpath + fname[:-4] + "-gt.png"
        gtimg = skimage.io.imread(gname)
        
        # convert to consecutive integers
        cl = unique(gtimg)
        gtimg0 = gtimg.copy().astype(float64)
        for i in range(len(cl)):
            gtimg0[gtimg==cl[i]] = i
        
        imgdata.append(img)
        gtdata.append(gtimg0)
print(len(imgdata))
# Out:
# 14

# %% [markdown]
# There are 14 images.  Each image also has a ground-truth segmentation that was created by a human annotation.  Here is an example:

# %%
plt.subplot(1,2,1)
plt.imshow(imgdata[6], aspect='equal')
plt.title('image')
plt.subplot(1,2,2)
plt.imshow(gtdata[6], aspect='equal', cmap='jet')
plt.title('segmentation');

# %% [markdown]
# ## 2. Clustering with Color Features
# To segment an image, we will extract features from each pixel location.  Then, we cluster the extracted features into groups.  Pixel location that are clustered into the same group form a segment.
#
# For the features, we will use the "Lab" colorspace, rather than the RGB colors.  Also, we will ignore the "L" feature, which is brightness, resulting in a 2-dimensional color feature space (a, b). Here are a few helper functions: 1) extract Lab features along a regular grid on the image; 2) convert cluster labels into a segmentation image; 3) color a segmentation image using colors from the original image.

# %%
def getfeatures(img, segm=None, stepsize=7, use_loc = False):
    """
    getfeatures - extract features from an image
     [X, Y, L] = getfeatures(img, stepsize)
     INPUT
     img      - the image   [type = np.ndarray or Image]
     segm     - the gt segmentation (optional)
     stepsize - window stepsize
     OUTPUT
      X   - the features: each row is a feature vector  [type = np.ndarray]
      Y   - the GT segment labels for each feature (if segm is provided)
      L   - dictionary containing location information of each feature
    """
    winsize = 7 # ensure it is an odd number
    if stepsize > winsize:
        raise Exception('stepsize larger than window size')
    # convert to LAB
    yimg = skimage.color.rgb2lab(img)

    offset = floor((winsize-1)/2)
    sy,sx, sc = img.shape

    if use_loc:
        Xdim = 4
    else:
        Xdim = 2
    
    # extract window patches with stepsize
    patches = skimage.util.view_as_windows(yimg, (winsize, winsize, 3), step=stepsize)    
    psize = patches.shape
    
    # get coordinates of windows
    rangex = arange(psize[1])*stepsize + offset
    rangey = arange(psize[0])*stepsize + offset

    X = zeros((psize[0] * psize[1], Xdim));
    
    if segm is None:
        Y = None
    else:
        Y = zeros((X.shape[0],))
    
    i = 0
    for x in range(psize[1]):
        for y in range(psize[0]):
            myu = mean(patches[y,x,0,:,:,1].flatten())
            myv = mean(patches[y,x,0,:,:,2].flatten())
            myy = int(rangey[y])
            myx = int(rangex[x])
            
            if use_loc:
                X[i,:] = [myu, myv, myx, myy]
            else:
                X[i,:] = [myu, myv]
                
            if Y is not None:
                Y[i] = segm[myy, myx]
                
            i = i + 1 
    
    L = {'rangex':rangex, 'rangey':rangey, 'offset':offset, 'sx':sx, 'sy':sy, \
         'stepsize':stepsize, 'winsize':winsize}
    return X, Y, L

def labels2seg(Y,L):
    """
    labels2segm - form a segmentation image using cluster labels
    segm = labels2segm(Y, L)
    Y - cluster labels for each location
    L - location dictionary from getfeatures
    segm - output segmentation image
    """
    segm = zeros((L['sy'], L['sx']))
    # <= offset if floor((winsize-1)/2)>= floor(stepsize/2) 
    rstep = int(floor(L['stepsize']/2.0)) 
    stepbox = range(-rstep, L['stepsize'] - rstep)
    rx = asarray(L['rangex'], dtype=int) + int(L['offset'])
    ry = asarray(L['rangey'], dtype=int) + int(L['offset'])
    Y_reshaped = Y.reshape((ry.size, rx.size),order='F')
    for i in stepbox:
        for j in stepbox:
            segm[ix_(ry + j, rx + i)] = Y_reshaped
    ## Now fil in the borders if they are missing
    minx = min(rx) + stepbox[0] - 1
    maxx = max(rx) + stepbox[-1] + 1
    miny = min(ry) + stepbox[0] - 1
    maxy = max(ry) + stepbox[-1] + 1

    if 0 <= minx:
        ## fill in left edge
        segm[:, 0:minx+1] = segm[:,minx+1].reshape((-1,1))
    if maxx < L['sx']:
        ## fill in right edge
        segm[:,maxx:] = segm[:,maxx-1].reshape((-1,1))
    if 0 < miny:
        ## fill in top edge
        segm[0:miny+1,:] = segm[miny+1,:].reshape((1,-1))
    if maxy < L['sy']:
        ## fill in bottom edge
        segm[maxy:,:] = segm[maxy-1,:].reshape((1,-1))
    return segm    

def colorsegms(segm, img):
    """
    colorsegm - color a segmentation based on the image
    csegm = colorsegm(segm, img)
    segm = the segmentation image  [type = np.ndarray]
    img = the original image    [type = np.ndarray (or Image)]
    csegm = the colored segmentation -- each segment is colored based on the 
            average pixel color within the segment.
    """
    img = asarray(img).copy()
    if segm.shape[0:2] != img.shape[0:2]:
        raise Exception('The shape of segmentation and image are not consistent') 
    rimg, gimg, bimg = img[:,:,0], img[:,:,1], img[:,:,2]
    for i in range(0, int(max(segm.flatten())) + 1):
        # assume label starts from 1
        ind = (segm == i)
        rimg[ind] = mean(rimg[ind].flatten())
        gimg[ind] = mean(gimg[ind].flatten())
        bimg[ind] = mean(bimg[ind].flatten())
    # handle outliers from DBSCAN
    ind = (segm == -1)
    rimg[ind] = 0
    gimg[ind] = 0
    bimg[ind] = 0
    return img

# %% [markdown]
# Next, we use the `getfeatures` function to extract features from an image.  `X` contains the feature vectors. `L` contains information about where each features was extracted, which is used later generate the segmentation.

# %%
# image to use
img = imgdata[6]
gt  = gtdata[6]

# extract features, each row is a feature vector
Xo,Ytrue, L = getfeatures(img, gt)
print(Xo.shape)

# normalize features
scaler = preprocessing.StandardScaler()  
X = scaler.fit_transform(Xo)

# view the image
plt.figure(figsize=(9,5))
plt.subplot(1,2,1)
plt.imshow(img, interpolation='nearest')
plt.title("image")

# view the features
plt.subplot(1,2,2)
plt.scatter(X[:,0], X[:,1], c='b', s=5, edgecolor='')
plt.ylabel('b'); plt.xlabel('a'); plt.grid(True)
# Out:
# (3060, 2)

# %% [markdown]
# Here is the segmented image, with the segment labels shown as colors.  The goal is to recoever these labels using clustering.

# %%
# view the image
plt.figure(figsize=(9,5))

plt.subplot(1,2,1)
plt.imshow(gt, interpolation='nearest', cmap='jet')
plt.title("true segmentation")

# view the features
plt.subplot(1,2,2)
plt.scatter(X[:,0], X[:,1], c=Ytrue, s=5, edgecolor='', cmap='jet')
plt.ylabel('b'); plt.xlabel('a'); plt.grid(True)

# %% [markdown]
# Now use a clustering algorithm to group the data into 5 clusters.

# %%
### INSERT YoUR CODE HERE

# %%
K = 5

km = cluster.KMeans(n_clusters=K, random_state=123)
Y = km.fit_predict(X)

# %% [markdown]
# Once you have the cluster labels (Y), use the below code to generate the segmentation image and view it.  You can also view the scatter plot with `showscatter`.

# %%
def showsegm(segm, img):
    "show a segmentation"
    
    # fill segmentation with colors from the image
    csegm = colorsegms(segm, img)
    
    # view the images, segmentation, and ground-truth
    plt.figure(figsize=(9,6))
    plt.subplot(2,2,1)
    plt.imshow(img, interpolation='nearest')
    plt.title('image')
    plt.subplot(2,2,2)
    plt.imshow(segm, interpolation='nearest', cmap='jet')
    plt.title('segmentation')
    plt.subplot(2,2,3)
    plt.imshow(csegm, interpolation='nearest')
    plt.title('segmentation w/ color')
    plt.subplot(2,2,4)
    plt.imshow(gt, interpolation='nearest', cmap='jet')
    plt.title("ground truth")
    
    return segm

def showscatter(X,Y):
    "show a scatter plot of clusters"
    
    if X.shape[1] == 2:
        plt.figure()
        plt.scatter(X[:,0], X[:,1], c=Y, s=5, edgecolor='', cmap='jet')
        plt.grid(True)
        plt.xlabel('a')
        plt.ylabel('b')
    else:
        plt.figure(figsize=(9,9))

        plt.subplot(2,2,1)
        plt.scatter(X[:,0], X[:,1], c=Y, s=5, edgecolor='', cmap='jet')
        plt.xlabel('a'); plt.ylabel('b'); plt.grid(True)

        plt.subplot(2,2,2)
        plt.scatter(X[:,2], X[:,3], c=Y, s=5, edgecolor='', cmap='jet')
        plt.xlabel('x-pos'); plt.ylabel('y-pos'); plt.grid(True)

        plt.subplot(2,2,3)
        plt.scatter(X[:,2], X[:,0], c=Y, s=5, edgecolor='', cmap='jet')
        plt.xlabel('x-pos'); plt.ylabel('a'); plt.grid(True)

        plt.subplot(2,2,4)
        plt.scatter(X[:,3], X[:,1], c=Y, s=5, edgecolor='', cmap='jet')
        plt.xlabel('y-pos'); plt.ylabel('b'); plt.grid(True)

# %%
# convert cluster labels to a segmentation image
segm = labels2seg(Y, L)

# show the segmentation
showsegm(segm, img)

# show the scatter plot
showscatter(X,Y)

# %% [markdown]
# Next we evaluate the segmentation with the ground-truth provided by a human annotator.  We cannot just check that the cluster assignments for each pixel are the same, since the cluster indices can be permuted.  We will use the _Adjusted Rand Index_, which calculates how often a pair of pixels is assigned correctly to the same cluster or not.  Use the below code to calculate the ARI. Higher values are better, and the maximum value is 1.

# %%
# calculate ARI
ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
print("ARI =",ari)
# Out:
# ARI = 0.3829192276756196

# %% [markdown]
# Try different clustering algorithms and settings (K, bandwidth, etc) to get the best segmentation as measured by ARI.

# %%
Ks = [2,3,4,5,6,7,8,9,10]
Kmeans_best_ari = 0.0;
Kmeans_best_classifier = cluster.KMeans(n_clusters=2, random_state=4487, n_jobs=-1);
Kmeans_best_param = 0;
for i in Ks:
    km = cluster.KMeans(n_clusters=i, random_state=4487, n_jobs=-1, verbose = 1)
    Yp = km.fit_predict(X)   # cluster data, and return labels
    segm = labels2seg(Yp, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    if(ari>Kmeans_best_ari):
        Kmeans_best_ari = ari
        Kmeans_best_classifier = km
        Kmeans_best_param = i
        
print("Best ari for Kmeans:", Kmeans_best_ari," with n_clusters =",Kmeans_best_param)
# Out:
# Best ari for Kmeans: 0.5345638794391061  with n_clusters = 4

# %%
Ks = [2,3,4,5,6,7,8,9,10]
Gmm_best_ari = 0.0;
Gmm_best_classifier = mixture.GaussianMixture(n_components=2, random_state=4487)
Gmm_best_param = 0;
for i in Ks:
    gmm = mixture.GaussianMixture(n_components=i, random_state=4487, n_init=10)
    gmm.fit(X)
    Y = gmm.predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(i))
    if(ari>=Gmm_best_ari):
        Gmm_best_ari = ari
        Gmm_best_classifier = gmm
        Gmm_best_param = i
        
print("Best ari for GMM:", Gmm_best_ari," with n_components =",Gmm_best_param)
# Out:
# 0.4303414098654236 for 2
# 0.5022144943459276 for 3
# 0.371506355366298 for 4
# 0.3426747759143915 for 5
# 0.2249745006176514 for 6
# 0.28420220043515115 for 7
# 0.2761198979491495 for 8
# 0.22580770180882576 for 9
# 0.2590671286940919 for 10
# Best ari for GMM: 0.5022144943459276  with n_components = 3

# %%
Ks = [2,3,4,5,6,7,8,9,10]
dpgmm_best_ari = 0.0;
dpgmm_best_classifier = mixture.BayesianGaussianMixture(covariance_type='full', 
                   weight_concentration_prior=1, 
                   n_components=5, max_iter=100, random_state=4487)
dpgmm_best_param = 0;
for i in Ks:
    dpgmm = mixture.BayesianGaussianMixture(covariance_type='full', 
                   weight_concentration_prior=0.1, 
                   n_components=i, max_iter=100, random_state=4487)
    dpgmm.fit(X)
    Y = dpgmm.predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(i))
    if(ari>=dpgmm_best_ari):
        dpgmm_best_ari = ari
        dpgmm_best_classifier = gmm
        dpgmm_best_param = i
        
print("Best ari for DPGMM:", dpgmm_best_ari," with n_components =",dpgmm_best_param)
# Out:
# 0.4303414098654236 for 2
# 0.33606034415098784 for 3
# D:\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# 0.3534727587858828 for 4
# 0.32536561036404654 for 5
# 0.21368257871713486 for 6
# 0.24521555509126297 for 7
# 0.20677332225690423 for 8
# 0.22039500558069472 for 9
# 0.29263650595246926 for 10
# Best ari for DPGMM: 0.4303414098654236  with n_components = 2

# %%
bw = [0.1, 0.2, 0.3, 0.5, 1.0, 1.5, 2.0,3,4,5]
ms_best_ari = 0.0;
ms_best_classifier = cluster.MeanShift(bandwidth=0.1, bin_seeding=True, n_jobs=-1)
ms_best_param = 0;
for i in bw:
    ms = cluster.MeanShift(bandwidth=i, bin_seeding=True, n_jobs=-1)
    Y = ms.fit_predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(i))
    if(ari>=ms_best_ari):
        ms_best_ari = ari
        ms_best_classifier = ms
        ms_best_param = i
        
print("Best ari for MS:", ms_best_ari," with bandwith =",ms_best_param)
# Out:
# 0.0460917433143085 for 0.1
# 0.15736231304871787 for 0.2
# 0.2886219166703868 for 0.3
# 0.23056857287399074 for 0.5
# 0.33416958237869965 for 1.0
# 0.4482796935333006 for 1.5
# 0.0 for 2.0
# 0.0 for 3
# 0.0 for 4
# 0.0 for 5
# Best ari for MS: 0.4482796935333006  with bandwith = 1.5

# %%
gammas = logspace(-2,1,5)
sc_best_ari = 0.0;
sc_best_classifier = cluster.SpectralClustering(n_clusters=1, affinity='rbf', gamma=0,
                                assign_labels='discretize', n_jobs=-1)
sc_best_K = 0;
sc_best_param = []
paramgrid = grid_search.ParameterGrid({'n_clusters':Ks,'gamma':gammas})
#ParameterGrid is used to create combinationsn of all parameters
for p in paramgrid:
    sc = cluster.SpectralClustering(affinity='rbf', assign_labels='discretize', n_jobs=-1, **p)
    Y = sc.fit_predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(p))
    if ari > sc_best_ari:
        sc_best_ari = ari
        sc_best_classifier = sc
print("Best ari for SC:", sc_best_ari," with parameters =", sc_best_classifier.get_params)
# Out:
# 0.4336998514659361 for {'gamma': 0.01, 'n_clusters': 2}
# 0.19839532044081848 for {'gamma': 0.01, 'n_clusters': 3}
# 0.49995094033283183 for {'gamma': 0.01, 'n_clusters': 4}
# 0.39568835332532865 for {'gamma': 0.01, 'n_clusters': 5}
# 0.359562584819874 for {'gamma': 0.01, 'n_clusters': 6}
# 0.361168643904565 for {'gamma': 0.01, 'n_clusters': 7}
# 0.36068526870866213 for {'gamma': 0.01, 'n_clusters': 8}
# 0.3581543137144012 for {'gamma': 0.01, 'n_clusters': 9}
# 0.3600789470787243 for {'gamma': 0.01, 'n_clusters': 10}
# 0.42751365996246965 for {'gamma': 0.05623413251903491, 'n_clusters': 2}
# 0.20722093195750613 for {'gamma': 0.05623413251903491, 'n_clusters': 3}
# 0.5120951478733813 for {'gamma': 0.05623413251903491, 'n_clusters': 4}
# 0.39576783105071184 for {'gamma': 0.05623413251903491, 'n_clusters': 5}
# 0.36223020870877576 for {'gamma': 0.05623413251903491, 'n_clusters': 6}
# 0.24106842399906778 for {'gamma': 0.05623413251903491, 'n_clusters': 7}
# 0.21685750606095897 for {'gamma': 0.05623413251903491, 'n_clusters': 8}
# 0.20744855815229168 for {'gamma': 0.05623413251903491, 'n_clusters': 9}
# 0.219273079269634 for {'gamma': 0.05623413251903491, 'n_clusters': 10}
# 0.43147246749138607 for {'gamma': 0.31622776601683794, 'n_clusters': 2}
# 0.22383807830492788 for {'gamma': 0.31622776601683794, 'n_clusters': 3}
# 0.535144345373199 for {'gamma': 0.31622776601683794, 'n_clusters': 4}
# 0.3128480027771666 for {'gamma': 0.31622776601683794, 'n_clusters': 5}
# 0.332246166394546 for {'gamma': 0.31622776601683794, 'n_clusters': 6}
# 0.2415935002479949 for {'gamma': 0.31622776601683794, 'n_clusters': 7}
# 0.23941544675153895 for {'gamma': 0.31622776601683794, 'n_clusters': 8}
# 0.22217052407884536 for {'gamma': 0.31622776601683794, 'n_clusters': 9}
# 0.238166152955957 for {'gamma': 0.31622776601683794, 'n_clusters': 10}
# 0.44876037344715947 for {'gamma': 1.7782794100389228, 'n_clusters': 2}
# 0.3326430030710849 for {'gamma': 1.7782794100389228, 'n_clusters': 3}
# 0.2002029008228739 for {'gamma': 1.7782794100389228, 'n_clusters': 4}
# 0.46542646742541643 for {'gamma': 1.7782794100389228, 'n_clusters': 5}
# 0.3314730935135743 for {'gamma': 1.7782794100389228, 'n_clusters': 6}
# 0.24317803530747456 for {'gamma': 1.7782794100389228, 'n_clusters': 7}
# 0.22962188055239993 for {'gamma': 1.7782794100389228, 'n_clusters': 8}
# 0.22166463489956376 for {'gamma': 1.7782794100389228, 'n_clusters': 9}
# 0.2718435426768845 for {'gamma': 1.7782794100389228, 'n_clusters': 10}
# 0.4539482876444683 for {'gamma': 10.0, 'n_clusters': 2}
# 0.34030483604706624 for {'gamma': 10.0, 'n_clusters': 3}
# 0.30067266130138015 for {'gamma': 10.0, 'n_clusters': 4}
# 0.22857422379128042 for {'gamma': 10.0, 'n_clusters': 5}
# 0.3383146262522518 for {'gamma': 10.0, 'n_clusters': 6}
# 0.32063219286709377 for {'gamma': 10.0, 'n_clusters': 7}
# 0.2604464474356289 for {'gamma': 10.0, 'n_clusters': 8}
# 0.2229416608099902 for {'gamma': 10.0, 'n_clusters': 9}
# 0.27083313333136044 for {'gamma': 10.0, 'n_clusters': 10}
# Best ari for SC: 0.535144345373199  with parameters = <bound method BaseEstimator.get_params of SpectralClustering(affinity='rbf', assign_labels='discretize', coef0=1,
#           degree=3, eigen_solver=None, eigen_tol=0.0,
#           gamma=0.31622776601683794, kernel_params=None, n_clusters=4,
#           n_init=10, n_jobs=-1, n_neighbors=10, random_state=None)>

# %%
minsamps = [5, 10, 15, 20]
eps = [0.05, 0.1, 0.15, 0.2, 0.25]
dbs_best_ari = 0.0;
dbs_best_classifier = cluster.DBSCAN(n_jobs=-1)
paramgrid = grid_search.ParameterGrid({'eps': eps, 'min_samples':minsamps})
#ParameterGrid is used to create combinationsn of all parameters
for p in paramgrid:
    sc = cluster.DBSCAN(**p, n_jobs=-1)
    Y = sc.fit_predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(p))
    if ari > dbs_best_ari:
        dbs_best_ari = ari
        dbs_best_classifier = sc
print("Best ari for DBS:", dbs_best_ari," with parameters =", dbs_best_classifier.get_params)
# Out:
# 0.12251050071753102 for {'eps': 0.05, 'min_samples': 5}
# 0.10459291335170408 for {'eps': 0.05, 'min_samples': 10}
# 0.04496752515834357 for {'eps': 0.05, 'min_samples': 15}
# 0.0015372844428344454 for {'eps': 0.05, 'min_samples': 20}
# 0.39120187680145013 for {'eps': 0.1, 'min_samples': 5}
# 0.2387732752028697 for {'eps': 0.1, 'min_samples': 10}
# 0.23310078420413047 for {'eps': 0.1, 'min_samples': 15}
# 0.14521353313137647 for {'eps': 0.1, 'min_samples': 20}
# -0.0030899239826459334 for {'eps': 0.15, 'min_samples': 5}
# 0.4062719979960164 for {'eps': 0.15, 'min_samples': 10}
# 0.3815401451172443 for {'eps': 0.15, 'min_samples': 15}
# 0.30102153980008384 for {'eps': 0.15, 'min_samples': 20}
# -0.0015362375841747667 for {'eps': 0.2, 'min_samples': 5}
# 0.4411182295903332 for {'eps': 0.2, 'min_samples': 10}
# 0.4267779666032063 for {'eps': 0.2, 'min_samples': 15}
# 0.4161520659680795 for {'eps': 0.2, 'min_samples': 20}
# -4.747414745204656e-05 for {'eps': 0.25, 'min_samples': 5}
# -0.0005651663654865574 for {'eps': 0.25, 'min_samples': 10}
# -0.0019635788885041198 for {'eps': 0.25, 'min_samples': 15}
# 0.437455775694247 for {'eps': 0.25, 'min_samples': 20}
# Best ari for DBS: 0.4411182295903332  with parameters = <bound method BaseEstimator.get_params of DBSCAN(algorithm='auto', eps=0.2, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=10, n_jobs=-1, p=None)>

# %%
print("Best ari for Kmeans:", Kmeans_best_ari," with n_clusters =",Kmeans_best_param)
print("Best ari for GMM:", Gmm_best_ari," with n_components =",Gmm_best_param)
print("Best ari for DPGMM:", dpgmm_best_ari," with n_components =",dpgmm_best_param)
print("Best ari for MS:", ms_best_ari," with bandwith =",ms_best_param)
print("Best ari for SC:", sc_best_ari," with parameters =", sc_best_classifier.get_params)
print("Best ari for DBS:", dbs_best_ari," with parameters =", dbs_best_classifier.get_params)
# Out:
# Best ari for Kmeans: 0.5345638794391061  with n_clusters = 4
# Best ari for GMM: 0.5022144943459276  with n_components = 3
# Best ari for DPGMM: 0.4303414098654236  with n_components = 2
# Best ari for MS: 0.0  with bandwith = 0
# Best ari for SC: 0.535144345373199  with parameters = <bound method BaseEstimator.get_params of SpectralClustering(affinity='rbf', assign_labels='discretize', coef0=1,
#           degree=3, eigen_solver=None, eigen_tol=0.0,
#           gamma=0.31622776601683794, kernel_params=None, n_clusters=4,
#           n_init=10, n_jobs=-1, n_neighbors=10, random_state=None)>
# Best ari for DBS: 0.4411182295903332  with parameters = <bound method BaseEstimator.get_params of DBSCAN(algorithm='auto', eps=0.2, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=10, n_jobs=-1, p=None)>

# %%
Y = Kmeans_best_classifier.predict(X)
segm = labels2seg(Y,L)
showsegm(segm, img)
showscatter(X,Y)
plt.title("Kmeans, ARI=" + str(Kmeans_best_ari))
plt.show()
Y = Gmm_best_classifier.predict(X)
segm = labels2seg(Y,L)
showsegm(segm, img)
showscatter(X,Y)
plt.title("GMM, ARI=" + str(Gmm_best_ari))
Y = dpgmm_best_classifier.predict(X)
segm = labels2seg(Y,L)
showsegm(segm, img)
showscatter(X,Y)
plt.title("DPGMM, ARI=" + str(dpgmm_best_ari))
plt.show()
Y = ms_best_classifier.predict(X)
segm = labels2seg(Y,L)
showsegm(segm, img)
showscatter(X,Y)
plt.title("MS, ARI=" + str(ms_best_ari))
Y = sc_best_classifier.fit_predict(X)
segm = labels2seg(Y,L)
showsegm(segm, img)
showscatter(X,Y)
plt.title("SC, ARI=" + str(sc_best_ari))
Y = dbs_best_classifier.fit_predict(X)
segm = labels2seg(Y,L)
showsegm(segm, img)
showscatter(X,Y)
plt.title("DBS, ARI=" + str(dbs_best_ari))
# Out:
# Text(0.5,1,'DBS, ARI=0.4411182295903332')

# %% [markdown]
# _Which algorithm performs the best?  Why?_
# - Kmeans and SC work the best.
# - Data is noisy. Other methods form small clusters around points.

# %% [markdown]
# ## 3. Color and Position Features
# You may notice that the segmentation is not spatially smooth -- that is, there are some "loner" pixels that are not the same cluster as the surrounding pixels.  This is because we are only clustering color.  One way to fix this is to include the (x,y) coordinate of the pixel as part of the feature vector.  This way, clusters will have pixels that are spatially close together.
#
# The below code extracts a 4-dimensional feature vector, where the first 2 features are the color channels and the last 2 features are the position.

# %%
# extract features with location
Xo,Ytrue,L = getfeatures(img, gt, use_loc=True)
print(Xo.shape)

# normalize features
scaler = preprocessing.StandardScaler()  
X = scaler.fit_transform(Xo)

# rescale position features
# larger values emphasize clustering by position more
X[:,2:4] *= 0.5
# Out:
# (3060, 4)

# %% [markdown]
# Here are plots of the 4 features.

# %%
showscatter(X, Ytrue)

# %% [markdown]
# Run clustering algorithms on the 4-dimensional data.  Try different algorithms and parameters to get the best ARI.

# %%
### INSERT YOUR CODE HERE

# %%
Ks = [2,3,4,5,6,7,8,9,10]
Kmeans_best_ari = 0.0;
Kmeans_best_classifier = cluster.KMeans(n_clusters=2, random_state=4487, n_jobs=-1);
Kmeans_best_param = 0;
for i in Ks:
    km = cluster.KMeans(n_clusters=i, random_state=4487, n_jobs=-1, verbose = 1)
    Yp = km.fit_predict(X)   # cluster data, and return labels
    segm = labels2seg(Yp, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    if(ari>Kmeans_best_ari):
        Kmeans_best_ari = ari
        Kmeans_best_classifier = km
        Kmeans_best_param = i
        
print("Best ari for Kmeans:", Kmeans_best_ari," with n_clusters =",Kmeans_best_param)
# Out:
# Best ari for Kmeans: 0.6030257121384394  with n_clusters = 4

# %%
Ks = [2,3,4,5,6,7,8,9,10]
Gmm_best_ari = 0.0;
Gmm_best_classifier = mixture.GaussianMixture(n_components=2, random_state=4487)
Gmm_best_param = 0;
for i in Ks:
    gmm = mixture.GaussianMixture(n_components=i, random_state=4487, n_init=10)
    gmm.fit(X)
    Y = gmm.predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(i))
    if(ari>=Gmm_best_ari):
        Gmm_best_ari = ari
        Gmm_best_classifier = gmm
        Gmm_best_param = i
        
print("Best ari for GMM:", Gmm_best_ari," with n_components =",Gmm_best_param)
# Out:
# 0.43415558206157095 for 2
# 0.25563418816247435 for 3
# 0.6441509602232454 for 4
# 0.621243638168083 for 5
# 0.43710060337635565 for 6
# 0.388719047868369 for 7
# 0.4237516644454377 for 8
# 0.3590011952589925 for 9
# 0.3393584568295504 for 10
# Best ari for GMM: 0.6441509602232454  with n_components = 4

# %%
Ks = [2,3,4,5,6,7,8,9,10]
dpgmm_best_ari = 0.0;
dpgmm_best_classifier = mixture.BayesianGaussianMixture(covariance_type='full', 
                   weight_concentration_prior=1, 
                   n_components=5, max_iter=100, random_state=4487)
dpgmm_best_param = 0;
for i in Ks:
    dpgmm = mixture.BayesianGaussianMixture(covariance_type='full', 
                   weight_concentration_prior=0.1, 
                   n_components=i, max_iter=100, random_state=4487)
    dpgmm.fit(X)
    Y = dpgmm.predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(i))
    if(ari>=dpgmm_best_ari):
        dpgmm_best_ari = ari
        dpgmm_best_classifier = gmm
        dpgmm_best_param = i
        
print("Best ari for DPGMM:", dpgmm_best_ari," with n_components =",dpgmm_best_param)
# Out:
# 0.43415558206157095 for 2
# 0.2667318738871078 for 3
# 0.6847875853234903 for 4
# 0.5107273490366675 for 5
# 0.42669143718078933 for 6
# D:\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# 0.46780755048228073 for 7
# 0.3079239248345741 for 8
# 0.3595839208525006 for 9
# 0.35158722353204486 for 10
# Best ari for DPGMM: 0.6847875853234903  with n_components = 4

# %%
bw = [0.1, 0.2, 0.3, 0.5, 1.0, 1.5, 2.0,3,4,5]
ms_best_ari = 0.0;
ms_best_classifier = cluster.MeanShift(bandwidth=0.1, bin_seeding=True, n_jobs=-1)
ms_best_param = 0;
for i in bw:
    ms = cluster.MeanShift(bandwidth=i, bin_seeding=True, n_jobs=-1)
    Y = ms.fit_predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(i))
    if(ari>=ms_best_ari):
        ms_best_ari = ari
        ms_best_classifier = ms
        ms_best_param = i
        
print("Best ari for MS:", ms_best_ari," with bandwith =",ms_best_param)
# Out:
# 0.0059342188159905935 for 0.1
# 0.03962178728320088 for 0.2
# 0.1142019866667421 for 0.3
# 0.32501632449452644 for 0.5
# 0.2736609057104809 for 1.0
# 0.45136310790204004 for 1.5
# 0.0 for 2.0
# 0.0 for 3
# 0.0 for 4
# 0.0 for 5
# Best ari for MS: 0.45136310790204004  with bandwith = 1.5

# %%
gammas = logspace(-2,1,5)
sc_best_ari = 0.0;
sc_best_classifier = cluster.SpectralClustering(n_clusters=1, affinity='rbf', gamma=0,
                                assign_labels='discretize', n_jobs=-1)
sc_best_K = 0;
sc_best_param = []
paramgrid = grid_search.ParameterGrid({'n_clusters':Ks,'gamma':gammas})
#ParameterGrid is used to create combinationsn of all parameters
for p in paramgrid:
    sc = cluster.SpectralClustering(affinity='rbf', assign_labels='discretize', n_jobs=-1, **p)
    Y = sc.fit_predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(p))
    if ari > sc_best_ari:
        sc_best_ari = ari
        sc_best_classifier = sc
print("Best ari for SC:", sc_best_ari," with parameters =", sc_best_classifier.get_params)
# Out:
# 0.41990152612980675 for {'gamma': 0.01, 'n_clusters': 2}
# 0.21510922118746495 for {'gamma': 0.01, 'n_clusters': 3}
# 0.28745094102935653 for {'gamma': 0.01, 'n_clusters': 4}
# 0.263835472552688 for {'gamma': 0.01, 'n_clusters': 5}
# 0.3233856310172132 for {'gamma': 0.01, 'n_clusters': 6}
# 0.3387509075534369 for {'gamma': 0.01, 'n_clusters': 7}
# 0.3341520606864613 for {'gamma': 0.01, 'n_clusters': 8}
# 0.27928586514718506 for {'gamma': 0.01, 'n_clusters': 9}
# 0.2837255281694755 for {'gamma': 0.01, 'n_clusters': 10}
# 0.4035694869374806 for {'gamma': 0.05623413251903491, 'n_clusters': 2}
# 0.22230077458096903 for {'gamma': 0.05623413251903491, 'n_clusters': 3}
# 0.33248657833785206 for {'gamma': 0.05623413251903491, 'n_clusters': 4}
# 0.4148884353616615 for {'gamma': 0.05623413251903491, 'n_clusters': 5}
# 0.2982447517424728 for {'gamma': 0.05623413251903491, 'n_clusters': 6}
# 0.3559057188544823 for {'gamma': 0.05623413251903491, 'n_clusters': 7}
# 0.30570791995195473 for {'gamma': 0.05623413251903491, 'n_clusters': 8}
# 0.2818132294591627 for {'gamma': 0.05623413251903491, 'n_clusters': 9}
# 0.283512439803928 for {'gamma': 0.05623413251903491, 'n_clusters': 10}
# 0.4343700944875641 for {'gamma': 0.31622776601683794, 'n_clusters': 2}
# 0.22654020182086157 for {'gamma': 0.31622776601683794, 'n_clusters': 3}
# 0.6027474680032514 for {'gamma': 0.31622776601683794, 'n_clusters': 4}
# 0.5604384067574534 for {'gamma': 0.31622776601683794, 'n_clusters': 5}
# 0.3281936664527778 for {'gamma': 0.31622776601683794, 'n_clusters': 6}
# 0.29369173873666804 for {'gamma': 0.31622776601683794, 'n_clusters': 7}
# 0.31892043256658065 for {'gamma': 0.31622776601683794, 'n_clusters': 8}
# 0.25744735305689853 for {'gamma': 0.31622776601683794, 'n_clusters': 9}
# 0.2835797282674021 for {'gamma': 0.31622776601683794, 'n_clusters': 10}
# 0.45419960355302647 for {'gamma': 1.7782794100389228, 'n_clusters': 2}
# 0.33831029513213046 for {'gamma': 1.7782794100389228, 'n_clusters': 3}
# 0.2206509610367292 for {'gamma': 1.7782794100389228, 'n_clusters': 4}
# 0.5511018675877902 for {'gamma': 1.7782794100389228, 'n_clusters': 5}
# 0.39569420244816284 for {'gamma': 1.7782794100389228, 'n_clusters': 6}
# 0.368696534121426 for {'gamma': 1.7782794100389228, 'n_clusters': 7}
# 0.26978202199732876 for {'gamma': 1.7782794100389228, 'n_clusters': 8}
# 0.28291037373413874 for {'gamma': 1.7782794100389228, 'n_clusters': 9}
# 0.26753915318857285 for {'gamma': 1.7782794100389228, 'n_clusters': 10}
# 0.47404791757083703 for {'gamma': 10.0, 'n_clusters': 2}
# 0.3952506083147156 for {'gamma': 10.0, 'n_clusters': 3}
# 0.3376821742885311 for {'gamma': 10.0, 'n_clusters': 4}
# 0.5925387699526578 for {'gamma': 10.0, 'n_clusters': 5}
# 0.5814958280482622 for {'gamma': 10.0, 'n_clusters': 6}
# 0.40770753030274975 for {'gamma': 10.0, 'n_clusters': 7}
# 0.39736680056658114 for {'gamma': 10.0, 'n_clusters': 8}
# 0.39563313011580376 for {'gamma': 10.0, 'n_clusters': 9}
# 0.3793936331098118 for {'gamma': 10.0, 'n_clusters': 10}
# Best ari for SC: 0.6027474680032514  with parameters = <bound method BaseEstimator.get_params of SpectralClustering(affinity='rbf', assign_labels='discretize', coef0=1,
#           degree=3, eigen_solver=None, eigen_tol=0.0,
#           gamma=0.31622776601683794, kernel_params=None, n_clusters=4,
#           n_init=10, n_jobs=-1, n_neighbors=10, random_state=None)>

# %%
minsamps = [5, 10, 15, 20]
eps = [0.05, 0.1, 0.15, 0.2, 0.25]
dbs_best_ari = 0.0;
dbs_best_classifier = cluster.DBSCAN(n_jobs=-1)
paramgrid = grid_search.ParameterGrid({'eps': eps, 'min_samples':minsamps})
#ParameterGrid is used to create combinationsn of all parameters
for p in paramgrid:
    sc = cluster.DBSCAN(**p, n_jobs=-1)
    Y = sc.fit_predict(X)
    segm = labels2seg(Y, L)
    ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
    print(str(ari) + " for " + str(p))
    if ari > dbs_best_ari:
        dbs_best_ari = ari
        dbs_best_classifier = sc
print("Best ari for DBS:", dbs_best_ari," with parameters =", dbs_best_classifier.get_params)
# Out:
# -0.00016484192196502162 for {'eps': 0.05, 'min_samples': 5}
# 0.0 for {'eps': 0.05, 'min_samples': 10}
# 0.0 for {'eps': 0.05, 'min_samples': 15}
# 0.0 for {'eps': 0.05, 'min_samples': 20}
# -0.020489144316027934 for {'eps': 0.1, 'min_samples': 5}
# -0.01675246638701213 for {'eps': 0.1, 'min_samples': 10}
# -0.0007283548922033108 for {'eps': 0.1, 'min_samples': 15}
# -0.0005411498758919064 for {'eps': 0.1, 'min_samples': 20}
# 0.18110537964328258 for {'eps': 0.15, 'min_samples': 5}
# 0.024503000903400882 for {'eps': 0.15, 'min_samples': 10}
# -0.012117877286065558 for {'eps': 0.15, 'min_samples': 15}
# -0.040139563867392626 for {'eps': 0.15, 'min_samples': 20}
# 0.2913524739948649 for {'eps': 0.2, 'min_samples': 5}
# 0.4236633575461211 for {'eps': 0.2, 'min_samples': 10}
# 0.1396352821581204 for {'eps': 0.2, 'min_samples': 15}
# 0.06094289357490085 for {'eps': 0.2, 'min_samples': 20}
# 0.38335776819955314 for {'eps': 0.25, 'min_samples': 5}
# 0.3436584577939989 for {'eps': 0.25, 'min_samples': 10}
# 0.4839005678980647 for {'eps': 0.25, 'min_samples': 15}
# 0.47086667096298224 for {'eps': 0.25, 'min_samples': 20}
# Best ari for DBS: 0.4839005678980647  with parameters = <bound method BaseEstimator.get_params of DBSCAN(algorithm='auto', eps=0.25, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=15, n_jobs=-1, p=None)>

# %%
print("Best ari for Kmeans:", Kmeans_best_ari," with n_clusters =",Kmeans_best_param)
print("Best ari for GMM:", Gmm_best_ari," with n_components =",Gmm_best_param)
print("Best ari for DPGMM:", dpgmm_best_ari," with n_components =",dpgmm_best_param)
print("Best ari for MS:", ms_best_ari," with bandwith =",ms_best_param)
print("Best ari for SC:", sc_best_ari," with parameters =", sc_best_classifier.get_params)
print("Best ari for DBS:", dbs_best_ari," with parameters =", dbs_best_classifier.get_params)
# Out:
# Best ari for Kmeans: 0.6030257121384394  with n_clusters = 4
# Best ari for GMM: 0.6441509602232454  with n_components = 4
# Best ari for DPGMM: 0.6847875853234903  with n_components = 4
# Best ari for MS: 0.45136310790204004  with bandwith = 1.5
# Best ari for SC: 0.6027474680032514  with parameters = <bound method BaseEstimator.get_params of SpectralClustering(affinity='rbf', assign_labels='discretize', coef0=1,
#           degree=3, eigen_solver=None, eigen_tol=0.0,
#           gamma=0.31622776601683794, kernel_params=None, n_clusters=4,
#           n_init=10, n_jobs=-1, n_neighbors=10, random_state=None)>
# Best ari for DBS: 0.4839005678980647  with parameters = <bound method BaseEstimator.get_params of DBSCAN(algorithm='auto', eps=0.25, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=15, n_jobs=-1, p=None)>

# %%
Y = Kmeans_best_classifier.predict(X)
segm = labels2seg(Y,L)
showscatter(X,Y)
plt.title("Kmeans, ARI=" + str(Kmeans_best_ari))
plt.show()
Y = Gmm_best_classifier.predict(X)
segm = labels2seg(Y,L)
showscatter(X,Y)
plt.title("GMM, ARI=" + str(Gmm_best_ari))
Y = dpgmm_best_classifier.predict(X)
segm = labels2seg(Y,L)
showscatter(X,Y)
plt.title("DPGMM, ARI=" + str(dpgmm_best_ari))
plt.show()
Y = ms_best_classifier.predict(X)
segm = labels2seg(Y,L)
showscatter(X,Y)
plt.title("MS, ARI=" + str(ms_best_ari))
Y = sc_best_classifier.fit_predict(X)
segm = labels2seg(Y,L)
showscatter(X,Y)
plt.title("SC, ARI=" + str(sc_best_ari))
Y = dbs_best_classifier.fit_predict(X)
segm = labels2seg(Y,L)
showscatter(X,Y)
plt.title("DBS, ARI=" + str(dbs_best_ari))
# Out:
# Text(0.5,1,'DBS, ARI=0.4839005678980647')

# %% [markdown]
# _Which method performs the best?  Why?_
# - Dirichlet Process Gaussian Mixture Model performs the best, followed by Kmeans and Special Clustering
# - Including the position allows better results. Kmeans and GMM only take the distance of points from the centre of each cluster
# into consideration.

# %% [markdown]
# _Does including the position features improve the segmentation results?_
# - Yes including the position feature provides better segmentation results. Reduces the effect of outliers.
